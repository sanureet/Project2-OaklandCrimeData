# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import db_user, db_password, db_host, db_port, db_name

# %%
# Read in crime data and place in a dataframe
csv_file = "../data/CrimeWatch_Data_2019-2020.csv"
crime_data_df = pd.read_csv(csv_file)
crime_data_df.head()
# Out:
#   crimetype  category  years casenumber  \
# 0     ARSON  Property   2019  19-000495
# 1     ARSON  Property   2019  19-000505
# 2     ARSON  Property   2019  19-000554
# 3     ARSON  Property   2019  19-001709
# 4     ARSON  Property   2019  19-001815
#
#                                   description policebeat            address  \
# 0                   MAL SET/ETC FIRE PROP/ETC        02Y        1800 9TH ST
# 1                   MAL SET/ETC FIRE PROP/ETC        31Z    10322 KNIGHT ST
# 2                   MAL SET/ETC FIRE PROP/ETC        34X   9314 PLYMOUTH ST
# 3  MAL SET/ETC FIRE PROP/ETC - MOTOR VEHICLES        07X  3445 SAN PABLO AV
# 4  MAL SET/ETC FIRE PROP/ETC - MOTOR VEHICLES        21Y      3100 DAVIS ST
#
#       city state                       location         lat        lng
# 0  Oakland    CA     POINT (-122.302 37.810199) -122.302000  37.810199
# 1  Oakland    CA  POINT (-122.181421 37.729727) -122.181421  37.729727
# 2  Oakland    CA  POINT (-122.169758 37.749289) -122.169758  37.749289
# 3  Oakland    CA  POINT (-122.278206 37.825691) -122.278206  37.825691
# 4  Oakland    CA  POINT (-122.220185 37.789836) -122.220185  37.789836

# %%
#crime_data_df[["pre-fix","coordinates"]]=crime_data_df.location_1.str.split("[",expand=True)

# %%
#crime_data_df.head()

# %%
#crime_data_df[["lat","lng"]]=crime_data_df.coordinates.str.split(",",expand=True)
#crime_data_df.head()

# %%
#crime_data_df[["lng","xx"]]=crime_data_df.lng.str.split("]",expand=True)
#crime_data_df.head()

# %%
# Create connection to Postgres SQL database
rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

engine = create_engine(rds_connection_string)

# %%
# Make sure to first set up the database (named same as what you have saved in the config file read in as dependency)
# Create tables from the columns in the dataframe
crime_data_df.to_sql(name='crimedata', con=engine, if_exists='append', index=False)

# %%
# Test to see if the tables were written to Postgres
engine.table_names()
# Out:
# C:\Users\mjensen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['crimedata']

# %%
#crime_data_df.to_json("../data/oakland_crime_data.json")

# %%
csv_file = "../data/crime_data_nb_df.csv"
crime_data_nb_df = pd.read_csv(csv_file)
crime_data_nb_df.head()
# Out:
#    Unnamed: 0 crimetype  category  years casenumber  \
# 0           0     ARSON  Property   2019  19-000495
# 1          23     ARSON  Property   2019  19-010479
# 2          97     ARSON  Property   2019  19-034869
# 3         169     ARSON  Property   2019  19-057875
# 4         250     ARSON  Property   2020  20-018241
#
#                                   description policebeat              address  \
# 0                   MAL SET/ETC FIRE PROP/ETC        02Y          1800 9TH ST
# 1                   MAL SET/ETC FIRE PROP/ETC        05Y    18TH ST & WOOD ST
# 2  MAL SET/ETC FIRE PROP/ETC - MOTOR VEHICLES        05Y  20TH ST & WILLOW ST
# 3          ARSON:INHABITED STRUCTURE/PROPERTY        02Y         1469 13TH ST
# 4                   MAL SET/ETC FIRE PROP/ETC        05Y         1719 15TH ST
#
#       city state                       location         lat        lng  \
# 0  Oakland    CA     POINT (-122.302 37.810199) -122.302000  37.810199
# 1  Oakland    CA  POINT (-122.295663 37.815999) -122.295663  37.815999
# 2  Oakland    CA  POINT (-122.293321 37.816695) -122.293321  37.816695
# 3  Oakland    CA  POINT (-122.293817 37.810544) -122.293817  37.810544
# 4  Oakland    CA   POINT (-122.296538 37.81358) -122.296538  37.813580
#
#                         geometry  index_right      NAME  count
# 0     POINT (-122.302 37.810199)          102  Prescott      1
# 1  POINT (-122.295663 37.815999)          102  Prescott      1
# 2  POINT (-122.293321 37.816695)          102  Prescott      1
# 3  POINT (-122.293817 37.810544)          102  Prescott      1
# 4   POINT (-122.296538 37.81358)          102  Prescott      1

# %%
# Create table from the columns in the dataframe
crime_data_nb_df.to_sql(name='crimedata_nb', con=engine, if_exists='append', index=False)

# %%
# Test to see if the tables were written to Postgres
engine.table_names()
# Out:
# C:\Users\mjensen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['crimedata', 'crimedata_nb']
